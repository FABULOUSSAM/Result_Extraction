# %%
import matplotlib.pyplot as plt
import cv2
from pylab import rcParams
from IPython.display import Image

# %%
import pytesseract
import requests
pytesseract.pytesseract.tesseract_cmd=r'C:\Users\Shubham\AppData\Local\Tesseract-OCR\tesseract.exe'
from PIL import Image
from PIL import ImageFilter

# %%
custom_config = r'--oem 3 --psm 6'
image =cv2.imread("./croppedone.png")
gry = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
blr = cv2.GaussianBlur(gry, (3, 3), 0)
val3=(pytesseract.image_to_string(blr, config=custom_config))
print(val3)
# Out:
# 7187002 MISHRA PRADEEP UMESHCHANDRA MANJU (ELECTIVE: CPE8031:MACHINE LEARNING)
# 41 15+ 49 16+ 46+ 13+ 32 14+ 18+ 35+
# o+ 17+ o+ 20+ 8+ 15+ 12 16+ rem: 40+ eB RLE
# 50 32 58 36 54 28 44 30 18 75
# 4D 624 1c 77 4D 6 24 1B 8 8 4D 6 24 1D 6 6 4p 416 1c 77 1B 8 8 6A 9 54 27° «178 6.59
# (DIPLOMA STUDENT) SGPI: SEM-III: 5.59 ; SEM-IV: 4.78 ; SEM-V: 5.68 ; SEM-VI: 0.00 ; SEM-VII: 0.00 3 CGPI: --

# %%
from PIL import Image
im = Image.open("./Crop_Image/crop_2.png") 
  
im.show()

# %%
image = Image.open('./Crop_Image/crop_2.png')
new_image = image.resize((2000, 500))
new_image.save('enlarge.png')
image =cv2.imread("./enlarge.png")
gry = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
blr = cv2.GaussianBlur(gry, (4, 4), 0)
val3=(pytesseract.image_to_string(blr, config=custom_config))
print(val3)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-19-2d6c624f5c80> in <module>
#       4 image =cv2.imread("./enlarge.png")
#       5 gry = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
# ----> 6 blr = cv2.GaussianBlur(gry, (2, 2), 0)
#       7 val3=(pytesseract.image_to_string(blr, config=custom_config))
#       8 print(val3)
#
# error: OpenCV(4.4.0) C:\Users\appveyor\AppData\Local\Temp\1\pip-req-build-9d_dfo3_\opencv\modules\imgproc\src\smooth.dispatch.cpp:297: error: (-215:Assertion failed) ksize.width > 0 && ksize.width % 2 == 1 && ksize.height > 0 && ksize.height % 2 == 1 in function 'cv::createGaussianKernels'

# %%
import easyocr
reader = easyocr.Reader(['en']) # need to run only once to load model into memory
newoutput=reader.readtext('./Crop_Image/crop_2.png',detail=0)
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
newoutput
# Out:
# ['7187002',
#  'MISHRA',
#  'PRADEEP',
#  'UMESHCHANDRA',
#  'MANJU',
#  '(ELECTIVE :',
#  'CPE8031',
#  'MACHINE LEARNING)',
#  '41',
#  '15+',
#  '49',
#  '16+',
#  '46 +',
#  '13+',
#  '32',
#  '14+',
#  '18+',
#  '35+',
#  '9 +',
#  '17-',
#  '9 +',
#  '20 +',
#  '8 +',
#  '15-',
#  '12',
#  '16+',
#  '40+',
#  'RLE',
#  '50',
#  '32',
#  '58',
#  '36',
#  '54',
#  '28',
#  '44',
#  '30',
#  '18',
#  '75',
#  '24',
#  '1 C',
#  '7',
#  '6 24',
#  '1 B',
#  '6 24',
#  '1 D',
#  '4  P',
#  '4 16',
#  '1 C',
#  '7   7',
#  '1 B',
#  'A',
#  '9 54',
#  '27',
#  '178',
#  '6 .59',
#  '(DIPLOMA  STUDENT)',
#  'SGPI:',
#  'SEM-III:',
#  '5.59',
#  'SEM-IV:',
#  '4 . 78',
#  'SEM-V:',
#  '5 . 68',
#  'SEM-VI :',
#  '0 . 00',
#  'SEM-VII:',
#  '0 . 00',
#  'CGPI :',
#  '4 D',
#  '4 D']

# %%
import pytesseract
import cv2
pytesseract.pytesseract.tesseract_cmd=r'C:\Users\Shubham\AppData\Local\Tesseract-OCR\tesseract.exe'

# %%
img = cv2.imread('./Crop_Image/crop_2.png')

# Adding custom options
custom_config = r'--oem 3 --psm 6'
pytesseract.image_to_string(img, config=custom_config)
# Out:
# '7187002 MISHRA PRADEEP UMESHCHANDRA MANJU (ELECTIVE: CPE8031:MACHINE LEARNING)\n41 15+ 49 16+ 46+ 13+ ga 14+ 18+ 35+\nO+ 17+ O+ 20+ 8+ 15+ 12 16+ mm: 40+ P RLE\n50 32 58 36 54 28 44 30 18 TS:\n4D 6 24 ic, F & 4D 6 24 1B 8 8 4D 6 24 1D 6 6 4p 4 16 ic * 7 1B 8 8 6A 9 54 27 178 6.59\n(DIPLOMA STUDENT) SGPI: SEM-III: 5.59 ; SEM-IV: 4.78 ; SEM-V: 5.68 ; SEM-VI: 0.00 ; SEM-VII: 0.00 ; CGPI: ——\n\x0c'

# %%
Image("./Crop_Image/crop_2.png")

# %%
import cv2
import numpy as np

# %%
img = cv2.imread('./Crop_Image/crop_2.png')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
blurred = cv2.GaussianBlur(gray, (5, 5), 0)
#edged = cv2.Canny(blurred, 50, 200, 255)
custom_config = r'--oem 3 --psm 6'
pytesseract.image_to_string(blurred, config=custom_config)
# Out:
# '7187002 MISHRA PRADEEP UMESHCHANDRA MANJU (ELECTIVE: CPE8031:MACHINE LEARNING)\n41 15+ 49 16+ 46+ 13+ 32 14+ 18+ 35+\n9+ 17+ 9+ 20+ 8+ 15+ 12 16+ as 40+ P RLE\n50 32 58 36 54 28 44 30 18 75\n4D 624 1c 77 4D 624 1B 8 8 4D 624 1D 66 4P 416 1c 77 1B 8 8 6A 9 54 27 «#178 6.59\n(DIPLOMA STUDENT) SGPI: SEM-III: 5.59 ; SEM-IV: 4.78 ; SEM-V: 5.68 ; SEM-VI: 0.00 ; SEM-VII: 0.00 # CGPI: --\n\x0c'

# %%
import easyocr
reader = easyocr.Reader(['en']) # need to run only once to load model into memory
newoutput=reader.readtext(blurred,detail=0)
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
newoutput
# Out:
# ['7187002',
#  'MISHRA',
#  'PRADEEP  UMESHCHANDRA MANJU',
#  '(ELECTIVE :',
#  'CPE803] :MACHINE  LEARNING)',
#  '41',
#  '15 +',
#  '49',
#  '16 -',
#  '46 +',
#  '13 -',
#  '32',
#  '14 -',
#  '18 =',
#  '35 +',
#  '9 +',
#  '17 -',
#  '9 +',
#  '20 +',
#  '8 +',
#  '15 -',
#  '12',
#  '16 +',
#  '40 +',
#  'RLE',
#  '50',
#  '32',
#  '5,8',
#  '36',
#  '5 4',
#  '2,8',
#  '44',
#  '30',
#  '18',
#  '7,5',
#  '6 24',
#  '1 C',
#  '6 24',
#  '1B',
#  '6 24',
#  '1D',
#  '416',
#  '1 C',
#  '7',
#  '1B',
#  '6 A',
#  "9'5 4",
#  '27',
#  '17,8',
#  '6 . 59',
#  '(DIPLOMA  STUDENT)',
#  'SGPI :',
#  'SEM-III:',
#  '5 . 5 9',
#  'SEM-IV:',
#  '4 .7,8',
#  'SEM-V:',
#  '5 . 6 8',
#  'SEM-VI:',
#  '0 .00',
#  'SEM-VII:',
#  '0 .00',
#  'CGPI :']

# %%
import pytesseract
import cv2
import numpy as np
import re
import pandas as pd

pytesseract.pytesseract.tesseract_cmd=r'C:\Users\Shubham\AppData\Local\Tesseract-OCR\tesseract.exe'
temp_head1=[]
header1={}
out=[]
store1=""
orderCount=0


img3 = cv2.imread('./Header_crop/crop2.png')
gray3 = cv2.cvtColor(img3, cv2.COLOR_BGR2GRAY)
blurred3 = cv2.GaussianBlur(gray3, (5, 5), 0)
#edged = cv2.Canny(blurred, 50, 200, 255)
custom_config = r'--oem 3 --psm 6'
val3=(pytesseract.image_to_string(blurred3, config=custom_config))
print(val3)
# Out:
# SEAT_NO NAME
# <----- Course-I -----> <----- Course-II ----> <---- Course-III ----> <----- Course-IV ----> < Course-V > < Course-VI >
# Th (80/32) Tw(25/10) Th (80/32) Tw (25/10) Th (80/32) Tw(25/10) Th (80/32) Tw(25/10) Tw (25/10) Tw (50/20)
# In (20/08) Or (25/10) In (20/08) Or (25/10) In (20/08) Or (25/10) In (20/08) Or (25/10) se Or (50/20) RESULT REMARK
# Tot Tot Tot Tot Tot Tot Tot Tot Tot Tot
# CG GP C*G CGGP C*G CG GP C*G CG GP C*G CG GP C*G CG GP C*G CG GP C*G CG GP C*G Cc G GP C*G C G GP C*G ac aCG SGPI

# %%
for x in range(0,len(val3)):
    store1+=val3[x]
    if ' ' in val3[x] or '\n' in val3[x]:
        temp_head1.append(store1)
        store1=""
for x in range(0,len(temp_head1)):
    if temp_head1[x].find('\n') != -1 :
        m = temp_head1[x].replace('\n','')
        temp_head1[x] = m
print(temp_head1)
target=['Th ','Tw ','In ','Or ']

for i in range(0,len(temp_head1)):
    if(temp_head1[i] in target) :
        out.append(temp_head1[i] + temp_head1[i+1])
        orderCount=1
    elif re.search("[0-9]",temp_head1[i]) and  temp_head1[i+2] not in target :
        orderCount = 0 
    elif orderCount != 0  and not(re.search("[0-9]",temp_head1[i])) and temp_head1[i] not in target:
        out.append('---')
        orderCount=0
           
for i in range(0,int(len(out)/2)):
    header1[i]=""
for x in range(0,int(len(out)/2)) :
    header1[x] = out[x % 10]
    header1[x] += '\n ' + out[x+int(len(out)/2)]
# Out:
# ['SEAT_NO ', 'NAME', '<----- ', 'Course-I ', '-----> ', '<----- ', 'Course-II ', '----> ', '<---- ', 'Course-III ', '----> ', '<----- ', 'Course-IV ', '----> ', '< ', 'Course-V ', '> ', '< ', 'Course-VI ', '>', 'Th ', '(80/32) ', 'Tw(25/10) ', 'Th ', '(80/32) ', 'Tw ', '(25/10) ', 'Th ', '(80/32) ', 'Tw(25/10) ', 'Th ', '(80/32) ', 'Tw(25/10) ', 'Tw ', '(25/10) ', 'Tw ', '(50/20)', 'In ', '(20/08) ', 'Or ', '(25/10) ', 'In ', '(20/08) ', 'Or ', '(25/10) ', 'In ', '(20/08) ', 'Or ', '(25/10) ', 'In ', '(20/08) ', 'Or ', '(25/10) ', 'se ', 'Or ', '(50/20) ', 'RESULT ', 'REMARK', 'Tot ', 'Tot ', 'Tot ', 'Tot ', 'Tot ', 'Tot ', 'Tot ', 'Tot ', 'Tot ', 'Tot', 'CG ', 'GP ', 'C*G ', 'CGGP ', 'C*G ', 'CG ', 'GP ', 'C*G ', 'CG ', 'GP ', 'C*G ', 'CG ', 'GP ', 'C*G ', 'CG ', 'GP ', 'C*G ', 'CG ', 'GP ', 'C*G ', 'CG ', 'GP ', 'C*G ', 'Cc ', 'G ', 'GP ', 'C*G ', 'C ', 'G ', 'GP ', 'C*G ', 'ac ', 'aCG ', 'SGPI', '\x0cSEAT_NO ', 'NAME', '<----- ', 'Course-I ', '-----> ', '<----- ', 'Course-II ', '-
# ...

# %%
print(header1)
# Out:
# {0: 'Th (80/32) \n Or (25/10) ', 1: 'Th (80/32) \n In (20/08) ', 2: 'Tw (25/10) \n Or (25/10) ', 3: 'Th (80/32) \n In (20/08) ', 4: 'Th (80/32) \n Or (25/10) ', 5: 'Tw (25/10) \n In (20/08) ', 6: 'Tw (50/20)\n Or (25/10) ', 7: 'In (20/08) \n ---'}

# %%
l=['SEAT_NO ', ' NAME', ' <----- ', ' Course-I ', ' -----> ', ' <----- ', ' Course-II ', ' ----> ', ' <---- ', ' Course-III ', ' ----> ', ' <----- ', ' Course-IV ', ' ----> ', ' < ', ' Course-V ', ' > ', ' < ', ' Coursé-VI ', ' >', ' Th ', ' (80/32) ', ' Tw(25/10) ', ' 
Th ', ' (80/32) ', ' Tw ', ' (25/10) ', ' Th ', ' (80/32) ', ' Tw(25/10) ', ' Th ', ' (80/32) ', ' Tw(25/10) ', ' Tw ', ' (25/10) ', ' Tw ', ' (50/20)', ' In ', ' (20/08) ', ' Or ', ' (25/10) ', ' In ', ' (20/08) ', ' Or ', ' (25/10) ', ' In ', ' (20/08) ', ' Or ', ' 
(25/10) ', ' In ', ' (20/08) ', ' Or ', ' (25/10) ', ' > ', ' Or ', ' (50/20) ', ' RESULT ', ' REMARK', ' Tot ', ' Tot ', ' Tot ', ' Tot ', ' Tot ', ' Tot ', ' Tot ', ' Tot ', ' Tot ', ' Tot', ' CG ', ' GP ', ' C*G ', ' CG ', ' GP ', ' C*G ', ' CG ', ' GP ', ' C*G ', 
' CG ', ' GP ', ' C*G ', ' CG ', ' GP ', ' C*G ', ' CG ', ' GP ', ' C*G ', ' CG ', ' GP ', ' C*G ', ' CG ', ' GP ', ' C*G ', ' CG ', ' GP ', ' C*G ', ' CG ', ' GP ', ' C*G ', ' aC ', ' aCG ', ' SGPI']
