# %%
import matplotlib.pyplot as plt
import cv2
from pylab import rcParams
from IPython.display import Image
import pytesseract
import requests
pytesseract.pytesseract.tesseract_cmd=r'C:\Users\Shubham\AppData\Local\Tesseract-OCR\tesseract.exe'
from PIL import Image
from PIL import ImageFilter
custom_config = r'--oem 3 --psm 6'

# %%
import numpy as np
import cv2
from IPython.display import Image,display
img = cv2.imread("./Crop_Image/crop_2.png")
cv2.imwrite("./synt.png", img)
display(Image("./synt.png"))

# %%
import numpy as np
import cv2
from IPython.display import Image,display
img = cv2.imread("./Crop_Image/crop_2.png")
gry = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

cv2.imwrite("./synt.png", gry)
display(Image("./synt.png"))

# %%
val3=(pytesseract.image_to_string(blurred3, config=custom_config))
print(val3)
# Out:
# 7187002 MISHRA PRADEEP UMESHCHANDRA MANJU (ELECTIVE: CPE8031:MACHINE LEARNING)
# 41 15+ 49 16+ 46+ 13+ 32 14+ 18+ 35+
# 9+ 17+ 9+ 20+ 8+ 15+ 12 16+ as 40+ P RLE
# 50 32 58 36 54 28 44 30 18 75
# 4D 624 1c 77 4D 624 1B 8 8 4D 624 1D 66 4P 416 1c 77 1B 8 8 6A 9 54 27 «#178 6.59
# (DIPLOMA STUDENT) SGPI: SEM-III: 5.59 ; SEM-IV: 4.78 ; SEM-V: 5.68 ; SEM-VI: 0.00 ; SEM-VII: 0.00 # CGPI: --

# %%
from PIL import Image
image = Image.open('./Crop_Image/crop_2.png')
new_image = image.resize((2000, 500))
new_image.save('resize.png')

# %%
import numpy as np
import cv2
from IPython.display import Image,display
img = cv2.imread("./resize.png")
img = cv2.cvtColor(image1, cv2.COLOR_BGR2GRAY)
thresh1 = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY, 199, 5)
#gry = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#blurred3 = cv2.GaussianBlur(gry, (5, 5), 0)
cv2.imwrite("./synt.png", thresh1)
display(Image("./synt.png"))
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-38-5da1799ed895> in <module>
#       3 from IPython.display import Image,display
#       4 img = cv2.imread("./resize.png")
# ----> 5 thresh1 = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY, 199, 5)
#       6 #gry = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#       7 #blurred3 = cv2.GaussianBlur(gry, (5, 5), 0)
#
# error: OpenCV(4.4.0) C:\Users\appveyor\AppData\Local\Temp\1\pip-req-build-9d_dfo3_\opencv\modules\imgproc\src\thresh.cpp:1676: error: (-215:Assertion failed) src.type() == CV_8UC1 in function 'cv::adaptiveThreshold'

# %%
val3=(pytesseract.image_to_string(blurred3, config=custom_config))
print(val3)
# Out:
# 7187002 MISHRA PRADEEP UMESHCHANDRA MANJU (ELECTIVE: CPEG031:MACHINE LEARNING)
# 4] 15+ 49 16+ 46+ 13+ 2 14+ 18+ 35+
# 9+ 17+ 9+ 20+ 8+ 15+ 12 16+ -- 40+ P RLE
# 50 32 58 36 54 28 44 30 18 15
# 4) 624 1077 40 624 18 88 40624 1066 42 416 1077 1888 6A 954 27 178 = 6.59
# (DIPLOMA STUDENT) SGPT: SEM-III: 5.59 ; SEM-IV: 4.78 + SEM-V: 5.68 ; SEM-VI: 0.00 ; SEM-VII: 0.00 ; CGPI: --

# %%
import cv2 
import numpy as np 
   
# path to input image is specified and  
# image is loaded with imread command 
image1 = cv2.imread('./Crop_Image/crop_2.png') 
   
# cv2.cvtColor is applied over the
# image input with applied parameters
# to convert the image in grayscale 
img = cv2.cvtColor(image1, cv2.COLOR_BGR2GRAY)
   
# applying different thresholding 
# techniques on the input image
thresh1 = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_MEAN_C,
                                          cv2.THRESH_BINARY, 199, 5)
  
thresh2 = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
                                          cv2.THRESH_BINARY, 199, 5)
  
# the window showing output images
# with the corresponding thresholding 
# techniques applied to the input image

# %%
import cv2 
import numpy as np 
   
blurred1 = cv2.GaussianBlur(thresh1, (5, 5), 0)
blurred2 = cv2.GaussianBlur(thresh2, (5, 5), 0)
cv2.imshow('Adaptive Mean', blurred1)
cv2.imshow('Adaptive Gaussian', blurred2)
if cv2.waitKey(0) & 0xff == 27: 
    cv2.destroyAllWindows()

# %%
val3=(pytesseract.image_to_string(blurred1, config=custom_config))
print(val3)
# Out:
# —— ee ee ee ee ee eee eee ee ee eee ee ee el
# 7187002 MISHRA PRADEEP UMESHCHANDRA MANJU. (ELECTIVE: @PE8Q31:MACHINE LEARNING)
# 41 15+ 49 16+ 464 13+ 32 i+ 18+ 35+
# o+ IT+ oF 20+ 4. 18+ 12 16+ -- 40+ 2 REE
# 50 32 58 36 54 28 44 30 18 15
# 4p 624 1¢77 4D 624 183 8 8 4D 624 1D 66 47 416 16¢77 #218 8 8 6A 954 27 178 «6.59
# (DIPLOMA STUDENT) SGPI: SEM-III: 5.59 ; SEM-IV: 4.78 ; SEM-V: 5.68 ; SEM-VI: 0.00 ; SEM-VII: 0.00 ¢ CGPI: --

# %%
import numpy as np
import cv2

img = cv2.imread('./Crop_Image/crop_2.png',0)
kernel = np.ones((5,5),np.uint8)
erosion = cv2.erode(img,kernel,iterations = 1)
dilation = cv2.dilate(erosion,kernel,iterations = 2)
cv2.imshow('Adaptive Mean', dilation)

if cv2.waitKey(0): 
    cv2.destroyAllWindows()
