# %%
import pandas as pd

# %%
data=pd.read_excel("./newextract.xlsx")

# %%
data
# Out:
#       SEAT NO                                  NAME OF STUDENT   STATUS  \
# 0         NaN                                              NaN      NaN
# 1   7187001.0   SHAIKH  GULAM  JILANI  SHAKIL  AHMED  SULTANA         P
# 2   7187002.0            MISHRA  PRADEEP  UMESHCHANDRA  MANJU    P  RLE
# 3   7187003.0                ISTALKAR  SUMEDH  DAGDU  MANISHA         F
# 4   7187004.0                    PATEL  VATSAL  PANKAJ  SARJU   Pp  RLE
# 5   7187005.0           /NANDGAONKAR  POOJA  BALARAM  DEVYANI         P
# 6   7187006.0   PRAJAPATI  SHAILESH  RAJENDRAPRASAD  MANORAMA    P  RLE
# 7   7187007.0               TILWANI  SAMRIDDH  NARESH  DIKSHA         P
# 8   7187008.0                 DEO  SWAPNIL  RAGHUNANDAN  LATA         F
# 9   7187009.0           MANE  ABHISHEK  NITYANAND  SANJEEVANI    P  RLE
# 10  7187010.0                    GABA  BHAVESH  SANJAY  KOMAL         P
# 11  7187011.0                  KACHHANI  RAHUL  PRAKASH  JAYA         P
# ...

# %%
info_1=data.shape
number_of_students=info_1[0]-1
print(number_of_students)
# Out:
# 23
